# %%
import sys
import os

sys.path.append(os.path.abspath('..'))

# %%
import pandas as pd
import json
import os
from tqdm.notebook import tqdm, trange
from evaluation.eval import run_evaluation

# %% [markdown]
# # Eval

# %%
# users = ['u_01', 'u_06','u_08',
#          'u_14','u_19','u_44',
#          'u_10','u_11','u_12']

# start_index = 0
# debug=False
# batch_size = 5

# for user in tqdm(users):
    
#     input_jsonl_path = f"../baselines/rule_base/data/output/rule_base_{user}.jsonl"
#     output_jsonl_path = f"data/rb/{user}.json"
#     progress_log_path = f"data/rb/log/{user}.txt"

#     run_evaluation(
#     input_jsonl_path=input_jsonl_path,
#     output_json_path=output_jsonl_path,
#     start_index=start_index,
#     llm_client=None,
#     batch_size=batch_size,
#     debug=debug,
#     progress_log_path=progress_log_path
#     )

# %% [markdown]
# # plots

# %%
import sys
import os

sys.path.append(os.path.abspath('..'))

from evaluation.plots.draw_plot import *

# %% [markdown]
# 01 - 06 - 08 ==> 0

# %%
# Define your methods dictionary
methods_dict = {
    'AGR':['data/agentic/agentic_u_01.json', 'data/agentic/agentic_u_06.json', 'data/agentic/agentic_u_08.json'],
    'RAG': ['data/rag/rag_u_01.json', 'data/rag/rag_u_06.json', 'data/rag/rag_u_08.json'],
    'DC': ['data/dc/dc_u_01.json', 'data/dc/dc_u_06.json', 'data/dc/dc_u_08.json'],
    'RB': ['data/rb/rb_u_01.json', 'data/rb/rb_u_06.json', 'data/rb/rb_u_08.json']
}

average_dict = {
    'AgRag':['data/average2/agentic_u_01.json', 'data/average2/agentic_u_06.json', 'data/average2/agentic_u_08.json'],
    'RAG': ['data/average2/rag_u_01.json', 'data/average2/rag_u_06.json', 'data/average2/rag_u_08.json'],
    'DC': ['data/average2/dc_u_01.json', 'data/average2/dc_u_06.json', 'data/average2/dc_u_08.json'],
    'RB': ['data/average2/rb_u_01.json', 'data/average2/rb_u_06.json', 'data/average2/rb_u_08.json']
}

# Plot average of all 4 keys
# process_and_save_batch_averages(methods_dict, 'data/average2')
plot_mae_analysis_from_averages(average_dict, 'Error Analysis: Users with no prior history in Database')

# %% [markdown]
# 14 - 19 - 44 ==> 21

# %%
# Define your methods dictionary
methods_dict = {
    'AGR':['data/agentic/agentic_u_14.json', 'data/agentic/agentic_u_19.json', 'data/agentic/agentic_u_44.json'],
    'RAG': ['data/rag/rag_u_14.json', 'data/rag/rag_u_19.json', 'data/rag/rag_u_44.json'],
    'DC': ['data/dc/dc_u_14.json', 'data/dc/dc_u_19.json', 'data/dc/dc_u_44.json'],
    'RB': ['data/rb/rb_u_14.json', 'data/rb/rb_u_19.json', 'data/rb/rb_u_44.json']
}

average_dict = {
    'AgRag':['data/average2/agentic_u_14.json', 'data/average2/agentic_u_19.json', 'data/average2/agentic_u_44.json'],
    'RAG': ['data/average2/rag_u_14.json', 'data/average2/rag_u_19.json', 'data/average2/rag_u_44.json'],
    'DC': ['data/average2/dc_u_14.json', 'data/average2/dc_u_19.json', 'data/average2/dc_u_44.json'],
    'RB': ['data/average2/rb_u_14.json', 'data/average2/rb_u_19.json', 'data/average2/rb_u_44.json']
}

# Plot average of all 4 keys
# process_and_save_batch_averages(methods_dict, 'data/average2')
plot_mae_analysis_from_averages(average_dict, 'Error Analysis: Users with 20% prior history in Database')

# %% [markdown]
# 10 - 11 - 12 ==> 51

# %%
# Define your methods dictionary
methods_dict = {
    'AGR':['data/agentic/agentic_u_10.json', 'data/agentic/agentic_u_11.json', 'data/agentic/agentic_u_12.json'],
    'RAG': ['data/rag/rag_u_10.json', 'data/rag/rag_u_11.json', 'data/rag/rag_u_12.json'],
    'DC': ['data/dc/dc_u_10.json', 'data/dc/dc_u_11.json', 'data/dc/dc_u_12.json'],
    'RB': ['data/rb/rb_u_10.json', 'data/rb/rb_u_11.json', 'data/rb/rb_u_12.json']
}

average_dict = {
    'AgRag':['data/average2/agentic_u_10.json', 'data/average2/agentic_u_11.json', 'data/average2/agentic_u_12.json'],
    'RAG': ['data/average2/rag_u_10.json', 'data/average2/rag_u_11.json', 'data/average2/rag_u_12.json'],
    'DC': ['data/average2/dc_u_10.json', 'data/average2/dc_u_11.json', 'data/average2/dc_u_12.json'],
    'RB': ['data/average2/rb_u_10.json', 'data/average2/rb_u_11.json', 'data/average2/rb_u_12.json']
}

# Plot average of all 4 keys
# process_and_save_batch_averages(methods_dict, 'data/average2')
plot_mae_analysis_from_averages(average_dict, 'Error Analysis: Users with 50% prior history in Database')
